# %%
# First let's import the packages we will use in this project
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# Read in the data
df = pd.read_csv(r'C:\Users\jfcom\OneDrive\Escritorio\Correlation in Python\data\movies.csv')

# %%
# Let's Look at the data

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# We need to see if we have any missing data
# Let's loop through the data and see if there is anything missing

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
#Data types for our columns

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df['budget'] = pd.to_numeric(df['budget'], errors='coerce').fillna(0).astype('int64')
df['gross']  = pd.to_numeric(df['gross'], errors='coerce').fillna(0).astype('int64')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
df['correct_year'] = df['released'].str.extract(r'(\d{4})').astype('Int64')

# %%
df = df.sort_values(by=['gross'], inplace= False, ascending = False)

# %%
#pd.set_option('display.max_rows', None)
pd.reset_option('display.max_rows')

# %%
# Drop any duplicates

df = df.drop_duplicates()

# %%
df
# Out:
#                                             name rating    genre  year  \
# 5445                                      Avatar  PG-13   Action  2009
# 7445                           Avengers: Endgame  PG-13   Action  2019
# 3045                                     Titanic  PG-13    Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13   Action  2015
# 7244                      Avengers: Infinity War  PG-13   Action  2018
# ...                                          ...    ...      ...   ...
# 1617                             Mortal Passions      R    Crime  1989
# 1614                              Edge of Sanity      R   Horror  1989
# 1606                                   I, Madman      R  Fantasy  1989
# 1601                        My Twentieth Century    NaN   Comedy  1989
# 7667                                   Tee em el    NaN   Horror  2020
#
#                                released  score      votes        director  \
# ...

# %%
# Scatter plot with budget vs gross
#sns.regplot(x="gross", y="budget", data=df)

plt.scatter(x=df['budget'], y = df['gross'])\

plt.title('Budget vs Gross Earnings')

plt.xlabel('Budget for Film')

plt.ylabel('Gross Earnings')


plt.show()

# %%
df
# Out:
#                                             name rating    genre  year  \
# 5445                                      Avatar  PG-13   Action  2009
# 7445                           Avengers: Endgame  PG-13   Action  2019
# 3045                                     Titanic  PG-13    Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13   Action  2015
# 7244                      Avengers: Infinity War  PG-13   Action  2018
# ...                                          ...    ...      ...   ...
# 1617                             Mortal Passions      R    Crime  1989
# 1614                              Edge of Sanity      R   Horror  1989
# 1606                                   I, Madman      R  Fantasy  1989
# 1601                        My Twentieth Century    NaN   Comedy  1989
# 7667                                   Tee em el    NaN   Horror  2020
#
#                                released  score      votes        director  \
# ...

# %%
# Plot the budget vs gross using SeaBorn

sns.regplot(x='budget', y='gross', data = df, scatter_kws={'color': 'red'}, line_kws={"color": 'blue'})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
# Let's start lookin at correlation

# %%
df.corr(numeric_only = True)
# Out:
#                   year     score     votes    budget     gross   runtime  \
# year          1.000000  0.097995  0.222945  0.309212  0.261900  0.120811
# score         0.097995  1.000000  0.409182  0.055665  0.186392  0.399451
# votes         0.222945  0.409182  1.000000  0.486862  0.632834  0.309212
# budget        0.309212  0.055665  0.486862  1.000000  0.750157  0.269510
# gross         0.261900  0.186392  0.632834  0.750157  1.000000  0.245235
# runtime       0.120811  0.399451  0.309212  0.269510  0.245235  1.000000
# correct_year  0.997415  0.105994  0.218429  0.300066  0.255026  0.120636
#
#               correct_year
# year              0.997415
# score             0.105994
# votes             0.218429
# budget            0.300066
# gross             0.255026
# runtime           0.120636
# correct_year      1.000000

# %%
correlation_matrix = df.corr(numeric_only = True)

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Numeric Features")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
df.groupby('company')['gross'].mean().sort_values(ascending=False)
# Out:
# company
# Marvel Studios                           1.255466e+09
# Illumination Entertainment               1.097122e+09
# Fairview Entertainment                   9.665549e+08
# B24                                      8.806815e+08
# Avi Arad Productions                     8.560852e+08
#                                              ...
# Embi Productions                         0.000000e+00
# Charlie Mopic                            0.000000e+00
# The Rejoycing Company                    0.000000e+00
# The South Australian Film Corporation    0.000000e+00
# K.G. Productions                         0.000000e+00
# Name: gross, Length: 2385, dtype: float64

# %%
# “While correlation is only meaningful between numeric variables, I also wanted to explore whether some production companies tend to generate higher gross revenue. 
# To do this, I grouped the data by company and calculated average gross revenue per company. This is not a correlation, but rather a comparison of group means.”

top_companies = df.groupby('company')['gross'].mean().sort_values(ascending=False).head(10)

top_companies.plot(kind='bar', title='Top 10 Companies by Average Gross Revenue')
plt.ylabel('Average Gross Revenue')
plt.xlabel('Company')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_numerized = df.copy()

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
df_numerized
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   533       5      0  2009       696    7.8  1100000.0      1155    1778
# 7445   535       5      0  2019       183    8.4   903000.0       162     743
# 3045  6896       5      6  1997       704    7.8  1100000.0      1155    1778
# 6663  5144       5      0  2015       698    7.8   876000.0      1125    2550
# 7244   536       5      0  2018       192    8.4   897000.0       162     743
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 1617  3712       6      5  1989      1277    4.5      274.0       117      82
# 1614  1745       6     10  1989        55    5.2     1300.0      1033    1743
# 1606  2691       6      8  1989       257    6.0     2900.0      2743     946
# 1601  3836      -1      4  1989      1160    7.1     1500.0      1105    1696
# 7667  5394      -1     10  2020       391    5.7        7.0      2165    3344
#
# ...

# %%
df
# Out:
#                                             name rating    genre  year  \
# 5445                                      Avatar  PG-13   Action  2009
# 7445                           Avengers: Endgame  PG-13   Action  2019
# 3045                                     Titanic  PG-13    Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13   Action  2015
# 7244                      Avengers: Infinity War  PG-13   Action  2018
# ...                                          ...    ...      ...   ...
# 1617                             Mortal Passions      R    Crime  1989
# 1614                              Edge of Sanity      R   Horror  1989
# 1606                                   I, Madman      R  Fantasy  1989
# 1601                        My Twentieth Century    NaN   Comedy  1989
# 7667                                   Tee em el    NaN   Horror  2020
#
#                                released  score      votes        director  \
# ...

# %%
correlation_matrix = df_numerized.corr(numeric_only = True)

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Numeric Features")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
correlation_matrix.corr()
# Out:
#                   name    rating     genre      year  released     score  \
# name          1.000000 -0.098392  0.011662 -0.116707 -0.103375 -0.104466
# rating       -0.098392  1.000000  0.164435 -0.165374 -0.041679 -0.141740
# genre         0.011662  0.164435  1.000000 -0.310631  0.048403 -0.095692
# year         -0.116707 -0.165374 -0.310631  1.000000 -0.145701  0.087678
# released     -0.103375 -0.041679  0.048403 -0.145701  1.000000 -0.054654
# score        -0.104466 -0.141740 -0.095692  0.087678 -0.054654  1.000000
# votes        -0.163963 -0.222270 -0.528203  0.307435 -0.163746  0.535873
# director     -0.076763 -0.053738 -0.029387 -0.230055 -0.098550 -0.160149
# writer       -0.073333 -0.091498  0.013785 -0.210069 -0.096719 -0.145482
# star         -0.061952 -0.043731 -0.002713 -0.209125 -0.039512 -0.149514
# country      -0.098831  0.061455 -0.133311 -0.260563 -0.119915 -0.387915
# budget       -0.124952 -0.338569 -0.719350  0.434879 -0.158006  0.123509
# ...

# %%
correlation_mat = df_numerized.corr()

corr_pairs = correlation_matrix.unstack()

corr_pairs
# Out:
# name          name            1.000000
#               rating         -0.008069
#               genre           0.016355
#               year            0.011453
#               released       -0.011311
#                                 ...
# correct_year  budget          0.300066
#               gross           0.255026
#               company        -0.015171
#               runtime         0.120636
#               correct_year    1.000000
# Length: 256, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs
# Out:
# budget        genre          -0.334021
# genre         budget         -0.334021
#               gross          -0.234297
# gross         genre          -0.234297
# votes         genre          -0.145307
#                                 ...
# year          year            1.000000
# genre         genre           1.000000
# rating        rating          1.000000
# runtime       runtime         1.000000
# correct_year  correct_year    1.000000
# Length: 256, dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]

high_corr
# Out:
# votes         gross           0.632834
# gross         votes           0.632834
# budget        gross           0.750157
# gross         budget          0.750157
# correct_year  year            0.997415
# year          correct_year    0.997415
# name          name            1.000000
# company       company         1.000000
# gross         gross           1.000000
# budget        budget          1.000000
# country       country         1.000000
# star          star            1.000000
# writer        writer          1.000000
# director      director        1.000000
# votes         votes           1.000000
# score         score           1.000000
# released      released        1.000000
# year          year            1.000000
# genre         genre           1.000000
# rating        rating          1.000000
# runtime       runtime         1.000000
# correct_year  correct_year    1.000000
# dtype: float64

# %%
# budget and gross have a strong positive correlation (~0.75), meaning higher budgets tend to be associated with higher gross revenue.

# votes and gross also have a moderately strong positive correlation (~0.63), suggesting movies with more votes tend to have higher gross.

# correct_year and year are almost perfectly correlated (~0.997), which makes sense if correct_year is a cleaned or derived version of year.
